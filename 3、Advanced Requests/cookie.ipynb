# %% [markdown]
# # request进阶
# ## 1、处理cookie，模拟用户登录。
# ### 1.1、模拟登录的session
# 原先这个网站是POST类型的，还没有反爬，现在有了反爬还是GET类型的，有种无力感席卷开来。
#
# 但是我们学习呢，还是照样先把POST的学习了。

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)

# %%
# 登录 -> 得到cookie
# 带着 cookie 去请求到书架url -> 书架上的内容。

# 我们可以使用session进行请求 -> session你可以认为是一连串的请求，在这个过程中的cookie不会丢失。
import requests

# 会话
session = requests.session()
data = {
    "loginName": "18614075987",
    "password": "q6035945"
}

# 1、登录
url = "https://passport.17k.com/ck/user/login"
resp = session.post(url, data=data)
print(resp.text)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# 后面就根据网址进去找就行了。
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 1.2、直接headers模拟cookie
# 这一种方法好一点，有cookie就直接干。

# %%
# 登录不如直接输入cookie
import requests

url = "https://user.17k.com/ck/author2/shelf?page=1&appKey=2406394919"

headers = {
    "GUID=2056bcc7-b083-4d83-b19b-62e2fce71124; Hm_lvt_9793f42b498361373512340937deb2a0=1725436273,1725532210; HMACCOUNT=353FB4796E59F59F; c_channel=0; c_csc=web; acw_tc=1a0c638b17255362328427712e011ad4ff3a555edf7ec4fe5f21a47dc247c8; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%222056bcc7-b083-4d83-b19b-62e2fce71124%22%2C%22%24device_id%22%3A%22191bc042238eaf-075848bb3a0b4b-26001151-1327104-191bc04223929a3%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_referrer%22%3A%22%22%2C%22%24latest_referrer_host%22%3A%22%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%2C%22first_id%22%3A%222056bcc7-b083-4d83-b19b-62e2fce71124%22%7D; Hm_lpvt_9793f42b498361373512340937deb2a0=1725537991; acw_sc__v2=66d99ed8f51aeb8bdc3d6cbb0de4a2ade89c8fc9; accessToken=avatarUrl%3Dhttps%253A%252F%252Fcdn.static.17k.com%252Fuser%252Favatar%252F19%252F79%252F79%252F103757979.jpg-88x88%253Fv%253D1725532508000%26id%3D103757979%26nickname%3Dhuanyizhiyuan%26e%3D1741090008%26s%3Dd85ba7e0609baa4e; tfstk=fPAigh0ELdWsFJwh-v5sHSFDBMDdfP1fdnFADsIqLMSCDVsOXE-DoUWV75-9KixexG5A6ChDnM5NhdIAXifDl30K2bhJ5F1fU0n-wYk1Xxf57S74D9zFPbmYzRcJ5FaUptGCybemwv2wQi-VQ6lFoMrVgtSZ-M7cP-rw0n8E-ZbY0i74QeSFzZ5V0n5q-ellrAS6gBREbR_VK2L2dBbGLvLlYQO-kwWGDFSn40R3gOjy7MVq2YuVaijBaDHHR3pwXwtmZDfyFHAcUscgVNver6SOaf414CQDyKYoqoQBQhAFnB3jCeAcjTRNKzPAT6_20tvIq7QG6pXksdgbYF-RjL56kzm9-TvhFwWUoR59eUdfUClgVMB5oHXJI0VM4goUL8-daS_EkB2bhO7C-gh9O_iBpKAEK203Uq6NRNs--22bhO7C-g3n-8lfQw_12; ssxmod_itna=QqjxRDnGKeq4yD0xBpxB4DKLORzKG8D5zDREeqnO8GEqGNK0oDZDiqAPGhDC845reQa0e3PAHG0QAuY4X+iD2L5Y0i10a6aIDB3DEx06xCQQeiilDCeDIDWeDiDG4Gm4qGtDpxG=DjDytZ9TtDm4GWDeDg/4Gg3erD03NBWdrD4qDBjgdDKw2g0DDl0GWQiGGuYDrDYSLeuwuMK7aK7DtDjwrD/4e12DtQy6HQ/k
G4HKSzDGSkU7iD===; ssxmod_itna2=QqjxRDnGKeq4yD0xBpxB4DKLORzKG8D5zDREeqnO8GxA=yiD/7CDFx2zU9Ih0IDxOG+7Tp6NR3Z0YqGYAh2ExIqGSAWXx93e6B9UwjhhdqO6KuZx6CD82G2xnjc9owrRzk5qTK78YH17jaks0pi6hiFo/pOXgF4ChrzPa5CqehQmcFFqQohlBo=ta57LO0IQCExvr3YCxbWngWojSeOojF+ZlSDpm5fpcWzO2TeT99LZKkkzRmxvDmxzS4DwawxreLsD2vnZAf9w9=T5AToDjKD+hhDD"
})

# print(resp.text)
# print(resp.json())

# 解析并打印书名、作者、描述、最新章节和书的类型
data = resp.json()['data']

for book in data:
    book_name = book['bookName']
    author_name = book['authorPenName']
    introduction = book['introduction']
    last_chapter = book['lastUpdateChapter']['name']
    book_type = book['bookCategory']['name']
    
    print(f"书名: {book_name}")
    print(f"作者: {author_name}")
    print(f"描述: {introduction}")
    print(f"最新章节: {last_chapter}")
    print(f"类型: {book_type}")
    print("-" * 50)
# Out:
# 书名: 我的透视超给力
# 作者: 番茄炖肉
# 描述: 我是老中医，专治各种吹牛逼！
# 我武道超神，吊打一切不服气！
# 秦飞偶得神秘传承，拥有神眼，从此医术通天，武道超神，且看他逆天崛起，笑傲人生。
# 最新章节: 第一千七百七十三章  就这点实力也跟我装？
# 类型: 都市异能
# --------------------------------------------------
# 书名: 分手后我成了前任的娇软白月光
# 作者: 欧阳元泉
# 描述: 13年痴情错付，云雪尧一朝醒悟，痛快分手退婚，“渣男如狗，且抛且走！”
# 重拾事业，她在职场中飒爽杀伐，惊艳众人。
# 曾经弃她如敝履的男人，却疯了似的缠她上瘾，“尧尧，嫁给我好不好？”
# 云雪尧潋滟轻笑：“霄爷如今，怎么活成了自己最讨厌的样子？”
# ——
# 用了整整七年去恨她，等到她决然转身，江凌霄才发现：所有的恨意都抵不过失去她的恐惧。
# “尧尧，我只求复合，不会逼你结婚。”
# “尧尧，我只求结婚，不会逼你生宝宝。”
# “尧尧，我们只生一个，不会让你多生……”
# 云雪尧揣着第三胎，忍无可忍，“江凌霄，你这个卑鄙小人！”
# 江凌霄：“尧尧，小人在你肚子里，我是你亲爱的。”
# 最新章节: 第322章 他的尧尧，回来了
# 类型: 总裁豪门
# --------------------------------------------------
# 书名: 农门长姐：我娇养了五个大佬弟弟
# 作者: 香奈儿不香
# 描述: 亲自带着百亿物资前往灾区赈灾的女霸总唐琪穿越开局就死娘，老爹征丁失踪，爷奶叔婶齐上阵要卖掉襁褓里的弟弟换粮食。
# 　　唐琪扬起扫帚，怒打极品血亲，化解危难后，看着三个小萝卜头弟弟，还有一个襁褓中的奶娃娃，她撸起袖子表示不要慌，有姐在就饿不死！
# 　　天无绝人之路，她的百亿物资竟然化作空间跟随她而来，唐琪凭着机智的头脑和天赋灵活使用百亿物资闷声发大财，斗渣渣、虐极品、送弟弟习文练武学医术，将他们养育成才。
# 　　后来--
# 　　少年将军：谁敢欺负我长姐，提头来见。
# 　　权臣首辅：谁敢辱骂我长姐，牢狱相会。
# 　　北周首富：谁敢骗财我长姐，赔个底掉。
# 　　鬼医传人：谁敢伤害我长姐，生不如死。
# ...
